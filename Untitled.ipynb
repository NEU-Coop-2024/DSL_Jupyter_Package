# %%
# %load_ext echo_append

# %%
# %%echo_append
# E: int
# P: int
# O: int
# (machines) P <- O
# (compilers) P <- E
# Out:
# Graph data: NODES
# =====
# Variable(variable_name=VName(id="E"), support=Support(support_type=SVocab['integer'], enum_group=None, ordering=None))
# Variable(variable_name=VName(id="P"), support=Support(support_type=SVocab['integer'], enum_group=None, ordering=None))
# Variable(variable_name=VName(id="O"), support=Support(support_type=SVocab['integer'], enum_group=None, ordering=None))
# EDGES
# =====
# P -> E
# P -> O

# %%
print('1234')
def int():
    P = 1;
    x = 2;
    y = 3;
    int = 4;
    print(P + x + y + int);
# Out:
# 1234

# %%
int()
# Out:
# 10
