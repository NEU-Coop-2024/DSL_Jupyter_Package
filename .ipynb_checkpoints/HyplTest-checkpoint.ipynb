# %%
# %load_ext jupyter_tikz

# %%
# %load_ext echo_append
# Out:
# /home/kyang/syntax_highlighting/echo_append/echo_append.py:6: SyntaxWarning: invalid escape sequence '\s'
#   grammar = Grammar("""

# %%
# %%echo_append
# E : num
# L : num
# P : num
# O : num
# (machines) P <- O
# (programs) P <- O
# (compilers) P <- O
# (machines) P <- E
# (programs) P <- L
# Out:
# {'nodes': ['E', 'L', 'P', 'O'], 'edges': [('O', 'P', '(machines) '), ('O', 'P', '(programs) '), ('O', 'P', '(compilers) '), ('L', 'O', '(machines) '), ('E', 'L', '(programs) '), ('E', 'P', '(machines) '), ('L', 'P', '(programs) ')]}
